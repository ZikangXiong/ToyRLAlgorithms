# %% [markdown]
# ## CS 285 Berkeley

# %%
# %%html
# <iframe width="1280" height="720" src="https://www.youtube.com/embed/7Lwf-BoIu3M?list=PLkFD6_40KJIwhWJpGazJ9VSj9CFMkb79A" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
# Out:
# <iframe width="1280" height="720" src="https://www.youtube.com/embed/7Lwf-BoIu3M?list=PLkFD6_40KJIwhWJpGazJ9VSj9CFMkb79A" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# ## Q function and Value function
# $Q^{\pi}\left(\mathbf{s}_{t}, \mathbf{a}_{t}\right)=\sum_{t^{\prime}=t}^{T} E_{\pi_{\theta}}\left[r\left(\mathbf{s}_{t^{\prime}}, \mathbf{a}_{t^{\prime}}\right) \mid \mathbf{s}_{t}, \mathbf{a}_{t}\right]$
#
# $\begin{aligned}
# &V^{\pi}\left(\mathbf{s}_{t}\right)=\sum_{t^{\prime}=t}^{T} E_{\pi_{\theta}}\left[r\left(\mathbf{s}_{t^{\prime}}, \mathbf{a}_{t^{\prime}}\right) \mid \mathbf{s}_{t}\right]: \text { total reward from } \mathbf{s}_{t}\\
# &V^{\pi}\left(\mathbf{s}_{t}\right)=E_{\mathbf{a}_{t} \sim \pi\left(\mathbf{a}_{t} \mid \mathbf{s}_{t}\right)}\left[Q^{\pi}\left(\mathbf{s}_{t}, \mathbf{a}_{t}\right)\right]\\
# &E_{\mathbf{s}_{1} \sim p\left(\mathbf{s}_{1}\right)}\left[V^{\pi}\left(\mathbf{s}_{1}\right)\right] \text { is the RL objective! }
# \end{aligned}$

# %% [markdown]
# ## Algorithm and Tips
#
# 1. Handle the correlation with replay buffer / parallel workers.
# ![image.png](attachment:dab20e81-467f-411c-8a25-f7fee1a30c1b.png)
#
# 2. Handle moving target with fixed target network
# ![image.png](attachment:7bf621b7-a356-4db7-b579-8b31fb318cb8.png)
#
# 3. Update target network with a damp coefficient
#
# ![image.png](attachment:04d746a4-46f3-4013-9d83-53fc95785f99.png)
#
# 4. Handle the over-estimation caused by argmax noise with double Q-Learning.
#
# ![image.png](attachment:b1a980f7-89f2-4171-af70-496e8f1757d4.png)
# ![image.png](attachment:e38e32de-3a9f-4a6b-a6b9-3fa4bf1eaa55.png)
#
# 5. When the Q function estimation is bad.
#
# ![image.png](attachment:3bc35aa8-dcc7-43c8-914b-e7e38fee5dc0.png)
#
# 6. Others
#
# ![image.png](attachment:b8c614ea-f389-4e05-9dce-8001ba68f474.png)
