# %% [markdown]
# # REINFORCE
#
# ## Policy Gradient

# %% [markdown]
# ![image.png](attachment:c7527bd0-41b8-496c-9e6f-9a816e006053.png)

# %% [markdown]
# $$
# \begin{array}{l}
# \nabla_{\theta} J(\theta)=E_{\tau \sim \pi_{\theta}(\tau)}\left[\left(\sum_{t=1}^{T} \nabla_{\theta} \log \pi_{\theta}\left(\mathbf{a}_{t} \mid \mathbf{s}_{t}\right)\right)\left(\sum_{t=1}^{T} r\left(\mathbf{s}_{t}, \mathbf{a}_{t}\right)\right)\right] \\
# \nabla_{\theta} J(\theta) \approx \frac{1}{N} \sum_{i=1}^{N}\left(\sum_{t=1}^{T} \nabla_{\theta} \log \pi_{\theta}\left(\mathbf{a}_{i, t} \mid \mathbf{s}_{i, t}\right)\right)\left(\sum_{t=1}^{T} r\left(\mathbf{s}_{i, t}, \mathbf{a}_{i, t}\right)\right)
# \end{array}
# $$
#
# ![image.png](attachment:10c5977e-9f41-4e3c-b1ce-ea877e3b00c1.png)

# %% [markdown]
# ![image.png](attachment:42252cc2-38cc-4216-b0e1-f0c15a5675d0.png)

# %% [markdown]
# ## Reduce Variance

# %% [markdown]
# ![image.png](attachment:71398b04-dc13-4040-905b-dc9c2c09b532.png)

# %% [markdown]
# ![image.png](attachment:25c15f89-4599-47de-91bb-08dacb16ae29.png)

# %% [markdown]
# On-policy is not sample efficient.
# The network changes after one gradient update.
#
# ![image.png](attachment:c48b1df9-1cd7-4fc1-9da6-9b7508cb351a.png)

# %% [markdown]
# ![image.png](attachment:6369ecce-334e-48c9-9c4a-f0e2b9889717.png)
